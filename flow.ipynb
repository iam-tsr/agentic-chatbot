# %%
from IPython.display import Image

from agents.orders_agent import orders_agent

Image(orders_agent.agent_graph.get_graph().draw_mermaid_png())

# %%
from IPython.display import Image

from agents.product_agent import product_QnA_agent

Image(product_QnA_agent.get_graph().draw_mermaid_png())

# %%
from IPython.display import Image

from agents.routing_agent import router_agent

Image(router_agent.router_graph.get_graph().draw_mermaid_png())
