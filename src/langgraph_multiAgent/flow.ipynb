# %%
from IPython.display import Image

from src.langgraph_multiAgent.doc_agent import product_agent

Image(product_agent.get_graph().draw_mermaid_png())

# %%
from IPython.display import Image

from src.langgraph_multiAgent.math_agent import maths_agent

Image(maths_agent.get_graph().draw_mermaid_png())

# %%
from IPython.display import Image

from src.langgraph_multiAgent.routing import router_agent

Image(router_agent.router_graph.get_graph().draw_mermaid_png())
